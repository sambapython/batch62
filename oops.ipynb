# %%
def fun():
    print("this is fun")
class Product:
    print("this is class..")
# Out:
# this is class..

# %%
def fun():
    print("this is fun")
class Product:
    print("this is class..")
    def get(x):
        print("this is get in class Product")
# Out:
# this is class..

# %%
class Product:
    print("this is class..")
    x=1000
    y=2000
    def get(a):
        print("this is get in class Product")
    print(x,y)
# Out:
# this is class..
# 1000 2000

# %%
class Product:
    print("this is class..")
    x=1000
    y=2000
    def get(a):
        print("this is get in class Product")
print(x,y)
# Out:
# this is class..
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d7b6e783ab47> in <module>()
#       5     def get(a):
#       6         print("this is get in class Product")
# ----> 7 print(x,y)
#
# NameError: name 'x' is not defined

# %%
class Product:
    print("this is class..")
    x=1000
    y=2000
    def get(a):
        print("this is get in class Product")
print(Product.x,Product.y)
# Out:
# this is class..
# 1000 2000

# %%
class Product:
    print("this is class..")
    x=1000
    y=2000
    def get(a):
        print("this is get in class Product")
print(Product.x,Product.y)
Product.get(10)
# Out:
# this is class..
# 1000 2000
# this is get in class Product

# %%
class Product:
    def create(a):
        print("this is product create method")
class Customer:
    def create(a):
        print("this is customer create method")
Product.create(10)
Customer.create(10)
# Out:
# this is product create method
# this is customer create method

# %%
class Product:
    def create(a):
        print("a:",a)
        print("cost:",a.cost,"name:",a.name)
        print("this is product create method")
class Customer:
    def create(a):
        print(a)
        print("this is customer create method")
# name, cost-->product
# name, address-->customer
minote7pro = Product()# Product() is a data object, minote7pro is a reference of the data object
minote7pro.name="minote7pro"
minote7pro.cost=17000
samsunggalaxy  = Product()
samsunggalaxy.name="samsunggalaxy"
samsunggalaxy.cost=10000
Product.create(minote7pro)
Product.create(samsunggalaxy)
# Out:
# a: <__main__.Product object at 0x7f6e48203e48>
# cost: 17000 name: minote7pro
# this is product create method
# a: <__main__.Product object at 0x7f6e48203da0>
# cost: 10000 name: samsunggalaxy
# this is product create method

# %%
class Product:
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
class Customer:
    def create(a):
        print(a)
        print("this is customer create method")
# name, cost-->product
# name, address-->customer
minote7pro = Product()# Product() is a data object, minote7pro is a reference of the data object
minote7pro.name="minote7pro"
minote7pro.cost=17000
samsunggalaxy  = Product()
samsunggalaxy.name="samsunggalaxy"
samsunggalaxy.cost=10000
Product.create(minote7pro)
Product.create(samsunggalaxy)
# Out:
# cost: 17000 name: minote7pro
# insert data:
# cost: 10000 name: samsunggalaxy
# insert data:

# %%
class Product:
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
class Customer:
    def create(a):
        print(a.name,a.address)
        print("this is customer create method")
cust1 = Customer()
cust1.name="Customer1"
cust1.address="address1"
Customer.create(cust1)
# Out:
# Customer1 address1
# this is customer create method

# %%
class Product:
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
class Customer:
    def create(a):
        print(a.name,a.address)
        print("this is customer create method")
cust1 = Customer()
cust1.name="Customer1"
cust1.address="address1"
Customer.create(cust1)
cust2 = Customer()
cust2.name="Customer2"
cust2.address = "Address2"
Customer.create(cust2)
# Out:
# Customer1 address1
# this is customer create method
# Customer2 Address2
# this is customer create method

# %%
class Product:
    def set_data(x, p_name, p_cost):
        x.name=p_name
        x.cost=p_cost
        
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
minote7pro = Product()# Product() is a data object, minote7pro is a reference of the data object
Product.set_data(minote7pro,"minote7pro",1700)
#minote7pro.name="minote7pro"
#minote7pro.cost=17000
samsunggalaxy  = Product()
Product.set_data(samsunggalaxy,"samsunggalaxy",10000)
#samsunggalaxy.name="samsunggalaxy"
#samsunggalaxy.cost=10000
Product.create(minote7pro)
Product.create(samsunggalaxy)
# Out:
# cost: 1700 name: minote7pro
# insert data:
# cost: 10000 name: samsunggalaxy
# insert data:

# %%
class Product:
    def set_data(x, p_name, p_cost):
        x.name=p_name
        x.cost=p_cost  
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
minote7pro = Product()
Product.set_data(minote7pro,"minote7pro",1700)
samsunggalaxy  = Product()
Product.set_data(samsunggalaxy,"samsunggalaxy",10000)
Product.create(minote7pro)
Product.create(samsunggalaxy)
# Out:
# cost: 1700 name: minote7pro
# insert data:
# cost: 10000 name: samsunggalaxy
# insert data:

# %%
class Product: # Product is class object
    def set_data(x, p_name, p_cost):
        x.name=p_name
        x.cost=p_cost  
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
minote7pro = Product()
#Product.set_data(minote7pro,"minote7pro",1700)
minote7pro.set_data("minote7pro",1700)
samsunggalaxy  = Product()
#Product.set_data(samsunggalaxy,"samsunggalaxy",10000)
samsunggalaxy.set_data("samsunggalaxy",10000)                    
#Product.create(minote7pro)
minote7pro.create()                   
#Product.create(samsunggalaxy)
samsunggalaxy.create()
# Out:
# cost: 1700 name: minote7pro
# insert data:
# cost: 10000 name: samsunggalaxy
# insert data:

# %%
class Product: # Product is class object
    def set_data(x, p_name, p_cost):
        x.name=p_name
        x.cost=p_cost  
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
minote7pro = Product()# product() is data object, minote7pro is a reference of the data object, called it as an instance.
minote7pro.set_data("minote7pro",1700)
samsunggalaxy  = Product()
samsunggalaxy.set_data("samsunggalaxy",10000)                    
minote7pro.create()                   
samsunggalaxy.create()

# %%
# write an EMP class, take name, sal, perf_grade as attributes. write a sal calculation method, that calulates the 
# salary based oin the grade. If the grade=="A" increment 25%, B--> 10, C-->5, D--->1, any other grade is invalid grade.
# write a get method which will show name,sal,grade, updated_sal

# %%
class Product: # Product is class object
    def set_data(x, p_name, p_cost):
        x.name=p_name
        x.cost=p_cost  
    def create(a):
        print("cost:",a.cost,"name:",a.name)
        print("insert data:")
minote7pro = Product()# product() is data object, minote7pro is a reference of the data object, called it as an instance.
minote7pro.set_data("minote7pro",1700)
samsunggalaxy  = Product()
#samsunggalaxy.set_data("samsunggalaxy",10000)                    
minote7pro.create()                   
samsunggalaxy.create()
# Out:
# cost: 1700 name: minote7pro
# insert data:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-64919af2fa50> in <module>()
#      11 #samsunggalaxy.set_data("samsunggalaxy",10000)
#      12 minote7pro.create()
# ---> 13 samsunggalaxy.create()
#
# <ipython-input-1-64919af2fa50> in create(a)
#       4         x.cost=p_cost
#       5     def create(a):
# ----> 6         print("cost:",a.cost,"name:",a.name)
#       7         print("insert data:")
#       8 minote7pro = Product()# product() is data object, minote7pro is a reference of the data object, called it as an instance.
#
# AttributeError: 'Product' object has no attribute 'cost'

# %%
class Emp:
    print("this is class")
# Out:
# this is class

# %%
class Emp:
    print("this is class")
    def get(x):
        print("this is get")
# Out:
# this is class

# %%
class Emp:
    print("this is class")
    def get(x):
        print("this is get")
    def __init__(x):
        print("this is init")
# Out:
# this is class

# %%
class Emp:
    print("this is class")
    def get(x):
        print("this is get")
    def __init__(x):
        print("this is init")
sai=Emp()
# Out:
# this is class
# this is init

# %%
class Emp:
    print("this is class")
    def get(x):
        print("this is get")
    def __init__(x):
        print("this is init")
sai=Emp()
vedha=Emp()
jay=Emp()
# Out:
# this is class
# this is init
# this is init
# this is init

# %%
class Product: 
    def __init__(self, p_name, p_cost):
        self.name=p_name
        self.cost=p_cost  
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
minote7pro = Product("minote7pro",1700)
samsunggalaxy  = Product("samsunggalaxy",10000)                  
minote7pro.create()                   
samsunggalaxy.create()
# Out:
# cost: 1700 name: minote7pro
# insert data:
# cost: 10000 name: samsunggalaxy
# insert data:

# %%
class Product: 
    def __init__(self, p_name, p_cost):
        self.name=p_name
        self.cost=p_cost  
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
minote7pro = Product("minote7pro",1700)
samsunggalaxy  = Product("samsunggalaxy",10000)                  
minote7pro.create()                   
samsunggalaxy.create()

# %%
def fun(x):
    print(x)

# %%
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.dis = dis
        self.act_cost = self.cost-(self.cost*self.dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.dis,self.act_cost
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)                  
print(minote7pro.get() )               
print(samsunggalaxy.get()    )
# Out:
# ('minote7pro', 1700, 2, 1666.0)
# ('samsunggalaxy', 10000, 3, 9700.0)

# %%
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.dis = dis
    def cost_cal(self):
        return self.cost-(self.cost*self.dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)                  
print(minote7pro.cost_cal())
# Out:
# 1666.0

# %%
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.dis = dis
    def cost_cal(self):
        return self.cost-(self.cost*self.dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)                  
print(minote7pro.cost_cal())
samsunggalaxy.dis=100
print(samsunggalaxy.cost_cal())
# Out:
# 1666.0
# 0.0

# %%
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.__dis = dis
    def cost_cal(self):
        print("considering dis:",self.__dis)
        return self.cost-(self.cost*self.__dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.__dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)                  
print(minote7pro.cost_cal())
samsunggalaxy.__dis=100
print(samsunggalaxy.cost_cal())
# Out:
# considering dis: 2
# 1666.0
# considering dis: 3
# 9700.0

# %%
role="emp"
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.__dis = dis
    def change_dis(self,new_dis):
        if role=="manager":
            self.__dis = new_dis
        else:
            print("no permission")
    def cost_cal(self):
        print("considering dis:",self.__dis)
        return self.cost-(self.cost*self.__dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.__dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)   
print(minote7pro.cost_cal())
samsunggalaxy.change_dis(100)
print(samsunggalaxy.cost_cal())
# Out:
# considering dis: 2
# 1666.0
# no permission
# considering dis: 3
# 9700.0

# %%
role="manager"
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.__dis = dis
    def change_dis(self,new_dis):
        if role=="manager":
            self.__dis = new_dis
        else:
            print("no permission")
    def cost_cal(self):
        print("considering dis:",self.__dis)
        return self.cost-(self.cost*self.__dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.__dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)   
print(minote7pro.cost_cal())
samsunggalaxy.change_dis(100)
print(samsunggalaxy.cost_cal())
# Out:
# considering dis: 2
# 1666.0
# considering dis: 100
# 0.0

# %%
role="manager"
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.__dis = dis
    def change_dis(self,new_dis):
        if role=="manager":
            self.__add_new_dis(new_dis)
        else:
            print("no permission")
    def __add_new_dis(self,new_dis):
        self.__dis = new_dis
    def cost_cal(self):
        print("considering dis:",self.__dis)
        return self.cost-(self.cost*self.__dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.__dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)   
print(minote7pro.cost_cal())
samsunggalaxy.change_dis(100)
print(samsunggalaxy.cost_cal())
# Out:
# considering dis: 2
# 1666.0
# considering dis: 100
# 0.0

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
o1=c1()
o1.op1()
# Out:
# this is op1 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def operations(self):
        self.op1()
o1=c1()
o1.operations()
# Out:
# this is op1 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
    def operations(self):
        self.op1()
        self.op2()
o1=c1()
o1.operations()
# Out:
# this is op1 in c1
# this is op2 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c2:
    def operations(self):
        o=c1()
        o.op1()
        o.op2()
        
o1=c2()
o1.operations()
# Out:
# this is op1 in c1
# this is op2 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c2:
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
        
o1=c2()
o1.operations()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-58b7fa32ffe7> in <module>()
#      11
#      12 o1=c2()
# ---> 13 o1.operations()
#
# <ipython-input-23-58b7fa32ffe7> in operations(self)
#       7     def operations(self):
#       8         #o=c1()
# ----> 9         self.op1()# accessing c1 class method using c2 class instance.
#      10         self.op2()
#      11
#
# AttributeError: 'c2' object has no attribute 'op1'

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c2(c1):
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
        
o1=c2()
o1.operations()
# Out:
# this is op1 in c1
# this is op2 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c2(c1):
    def op1(self):
        print("this is op1 in c2")
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
   
        
o1=c2()
o1.operations()
# Out:
# this is op1 in c2
# this is op2 in c1

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c3:
    def op3(self):
        print("this is op3 in c3")
class c2(c1):
    def op1(self):
        print("this is op1 in c2")
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
        self.op3()
        
o1=c2()
o1.operations()
# Out:
# this is op1 in c2
# this is op2 in c1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-13062c1b1e20> in <module>()
#      17
#      18 o1=c2()
# ---> 19 o1.operations()
#
# <ipython-input-26-13062c1b1e20> in operations(self)
#      14         self.op1()# accessing c1 class method using c2 class instance.
#      15         self.op2()
# ---> 16         self.op3()
#      17
#      18 o1=c2()
#
# AttributeError: 'c2' object has no attribute 'op3'

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c3:
    def op3(self):
        print("this is op3 in c3")
class c2(c1,c3):
    def op1(self):
        print("this is op1 in c2")
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
        self.op3()
        
o1=c2()
o1.operations()
# Out:
# this is op1 in c2
# this is op2 in c1
# this is op3 in c3

# %%
class c1:
    def op1(self):
        print("this is op1 in c1")
    def op2(self):
        print("this is op2 in c1")
class c3:
    def op3(self):
        print("this is op3 in c3")
    def op1(self):
        print("this is op1 in c3")
class c2(c1,c3):
    def op1(self):
        print("this is op1 in c2")
    def operations(self):
        #o=c1()
        self.op1()# accessing c1 class method using c2 class instance.
        self.op2()
        self.op3()
        
o1=c2()
o1.operations()
print(c2.__mro__) # method resolution order
# Out:
# this is op1 in c2
# this is op2 in c1
# this is op3 in c3
# (<class '__main__.c2'>, <class '__main__.c1'>, <class '__main__.c3'>, <class 'object'>)

# %%
role="manager"
class Product: 
    def __init__(self, p_name, p_cost,dis):
        self.name=p_name
        self.cost=p_cost
        self.__dis = dis
    def change_dis(self,new_dis):
        if role=="manager":
            self.__add_new_dis(new_dis)
        else:
            print("no permission")
    def __add_new_dis(self,new_dis):
        self.__dis = new_dis
    def cost_cal(self):
        print("considering dis:",self.__dis)
        return self.cost-(self.cost*self.__dis/100)
    def create(self):
        print("cost:",self.cost,"name:",self.name)
        print("insert data:")
    def get(self):
        return self.name,self.cost,self.__dis
minote7pro = Product("minote7pro",1700,2)
samsunggalaxy  = Product("samsunggalaxy",10000,3)   
print(minote7pro.cost_cal())
samsunggalaxy.change_dis(100)
print(samsunggalaxy.cost_cal())

# %%
l=[1,2,3,4]
l.append(10)
print(l)
# Out:
# [1, 2, 3, 4, 10]

# %%
d={1:2}
d.get(1)
# Out:
# 2

# %%
a=10

# %%
a=int(10)

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2:
    def __init__(self):
        print("this is init in c2")
o1=c1()
o2=c2()
# Out:
# this is init in c1
# this is init in c2

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
o2=c2()
# Out:
# this is init in c2

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
o2=c2()
# Out:
# this is init in c2

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2(c1):
    pass
o2=c2()
# Out:
# this is init in c1

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
    def sal_cal(self):
        print("this is sal_cal in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
    def get(self):
        print("this is get")
        
        
o2=c2()
o2.get()
# Out:
# this is init in c2
# this is get

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
    def sal_cal(self):
        print("this is sal_cal in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
    def get(self):
        print("this is get")
        
        
        
o2=c2()
o2.get()
o2.sal_cal()
# Out:
# this is init in c2
# this is get
# this is sal_cal in c1

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
    def sal_cal(self):
        print("this is sal_cal in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
    def get(self):
        print("this is get")
        self.sal_cal()
        
o2=c2()
o2.get()
# Out:
# this is init in c2
# this is get
# this is sal_cal in c1

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
    def sal_cal(self):
        print("this is sal_cal in c1")
    def get(self):
        print("this is get in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
    def get(self):
        print("this is get")
        self.sal_cal()
        self.get()
        
        
o2=c2()
o2.get()
# Out:
# this is init in c2
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# this is sal_cal in c1
# this is get
# ...

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
    def sal_cal(self):
        print("this is sal_cal in c1")
    def get(self):
        print("this is get in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
    def get(self):
        print("this is get")
        self.sal_cal()
        #self.get()
        c1.get(self)
        
        
o2=c2()
o2.get()
# Out:
# this is init in c2
# this is get
# this is sal_cal in c1
# this is get in c1

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
        c1.__init__(self) 
o2=c2()
# Out:
# this is init in c2
# this is init in c1

# %%
class c1:
    def __init__(self):
        print("this is init in c1")
class c2(c1):
    def __init__(self):
        print("this is init in c2")
        c1.__init__(self) 
o2=c2()
o2.__init__()
# Out:
# this is init in c2
# this is init in c1
# this is init in c2
# this is init in c1

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")

# %%
a=10
b=34
a+b
# Out:
# 44

# %%
a=10
b=34
#a+b
print(a.__add__(b))
print(int.__add__(a,b))
# Out:
# 44
# 44

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
sai+jay

# %%
s1="str1"
s2="str2"
s1+s2
# Out:
# 'str1str2'

# %%
str.__add__(s1,s2)
# Out:
# 'str1str2'

# %%
int.__add__(s1,s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6fc537626bbf> in <module>()
# ----> 1 int.__add__(s1,s2)
#
# TypeError: descriptor '__add__' requires a 'int' object but received a 'str'

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
sai+jay

# %%
d1={1:2,3:4}
d2={3:4,5:6}
d1+d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-49d15acab9a1> in <module>()
#       1 d1={1:2,3:4}
#       2 d2={3:4,5:6}
# ----> 3 d1+d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
sai+jay
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8feddd18e9f9> in <module>()
#       5 sai=Emp("sailaxmi","2")
#       6 jay=Emp("jayaram","3")
# ----> 7 sai+jay
#
# TypeError: unsupported operand type(s) for +: 'Emp' and 'Emp'

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return 10
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
# Out:
# 10

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
# Out:
#  sailaxmi is a mother of jayaram

# %%
print(10+20)
print([1,2,3,]+[4,5,6])
print("str1"+"str2")
print(1+2j+3+4j)
# Out:
# 30
# [1, 2, 3, 4, 5, 6]
# str1str2
# (4+6j)

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
for i in sai:
    print(i)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-10fc26eb6b23> in <module>()
#      11 print(sai+jay)
#      12 print(sai-jay)
# ---> 13 for i in sai:
#      14     print(i)
#
# TypeError: 'Emp' object is not iterable

# %%
for i in "python":
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in 1000:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d84c485ddbc3> in <module>()
# ----> 1 for i in 1000:
#       2     print(i)
#
# TypeError: 'int' object is not iterable

# %%
for i in {"k1":"v1","k2":"v2","k3":"v3"}:
    print(i)
# Out:
# k1
# k2
# k3

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
for i in sai:
    print(i)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-10fc26eb6b23> in <module>()
#      11 print(sai+jay)
#      12 print(sai-jay)
# ---> 13 for i in sai:
#      14     print(i)
#
# TypeError: 'Emp' object is not iterable

# %%
def fun():
    print("st1")
    return 10
    print("st2")
    return 20
    print("st3")
    return 30
res=fun()
print("res=",res)
# Out:
# st1
# res= 10

# %%
def fun():
    print("st1")
    yield 10
    print("st2")
    yield 20
    print("st3")
    yield 30
res=fun()
print("res=",res)
# Out:
# res= <generator object fun at 0x7f94483eee58>

# %%
def fun():
    print("st1")
    yield 10
    print("st2")
    yield 20
    print("st3")
    yield 30
res=fun()
print("res=",res)
for i in res:
    print("i=",i)
# Out:
# res= <generator object fun at 0x7f9448c6c930>
# st1
# i= 10
# st2
# i= 20
# st3
# i= 30

# %%
def fun():
    return [10,20,30]
res=fun()
print("res=",res)
for i in res:
    print("i=",i)
# Out:
# res= [10, 20, 30]
# i= 10
# i= 20
# i= 30

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
    def __iter__(self):
        yield 1
        yield 2
        yield 3
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
for i in sai:
    print(i)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram
# 1
# 2
# 3

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
    def __iter__(self):
        yield {"name":self.name}
        yield {"id":self.id}

sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
for i in sai:
    print(i)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram
# {'name': 'sailaxmi'}
# {'id': '2'}

# %%
class Emp:
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
    def __add__(self1,self2):
        return " %s is a mother of %s"%(self1.name,self2.name)
    def __sub__(self1,self2):
        return self1.name+self2.name
    def __iter__(self):
        for i in self.__dict__.items():
            yield i
sai=Emp("sailaxmi","2")
jay=Emp("jayaram","3")
print(sai+jay)
print(sai-jay)
for i in sai:
    print(i)
# Out:
#  sailaxmi is a mother of jayaram
# sailaxmijayaram
# ('name', 'sailaxmi')
# ('id', '2')

# %%
def fun(x,y=10,z=20):
    print(x,y,z)
fun(10)
fun(10,20)
fun(10,20,30)
# Out:
# 10 10 20
# 10 20 20
# 10 20 30

# %%
# method overloading
class Emp:
    def __init__(self,name,pan=None,adhar=None,dl=None):
        self.name=name
        self.pan=pan
        self.adhar=adhar
        self.dl=dl
    def get(self):
        return self.__dict__
sai = Emp("sailaxmi")
jay=Emp("jayaram",adhar="234werwe")
vedha = Emp("vedhanvesh",pan="dafsdsf",dl="234523efsd")
print(vedha.get())
print(jay.get())
print(sai.get())
# Out:
# {'name': 'vedhanvesh', 'pan': 'dafsdsf', 'adhar': None, 'dl': '234523efsd'}
# {'name': 'jayaram', 'pan': None, 'adhar': '234werwe', 'dl': None}
# {'name': 'sailaxmi', 'pan': None, 'adhar': None, 'dl': None}

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
    pass
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def validate_insert(self):
        print("validate the data")
        print("insert  the  %s in to table" % self.data)
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
    pass
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.validate_insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the data
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def validate_insert(self):
        print("validate the data")
        self.insert()
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
    pass
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.validate_insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the data
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def validate_insert(self):
        print("validate the data")
        self.insert()
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
    pass
class Product(DB):
    pass
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.validate_insert()
prod1 = Product({"name":"apple","table":"product","cost":23})
prod1.validate_insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the data
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table
# validate the data
# insert  the  {'name': 'apple', 'table': 'product', 'cost': 23} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
     def validate_insert(self):
        print("validate the address")
        self.insert()
class Product(DB):
     def validate_insert(self):
        print("validate the cost")
        self.insert()
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.validate_insert()
prod1 = Product({"name":"apple","table":"product","cost":23})
prod1.validate_insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the address
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table
# validate the cost
# insert  the  {'name': 'apple', 'table': 'product', 'cost': 23} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
     def validate_insert(self):
        print("validate the address")
        self.insert()
class Product(DB):
     def validate_insert(self):
        print("validate the cost")
        self.insert()
class Location(DB):
    def validate_insert(self):
        print("validate the name")
        self.insert()
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.validate_insert()
prod1 = Product({"name":"apple","table":"product","cost":23})
prod1.validate_insert()
hyd = Location({"name":"hyderabad","table":"location"})
hyd.insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the address
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table
# validate the cost
# insert  the  {'name': 'apple', 'table': 'product', 'cost': 23} in to table
# insert  the  {'name': 'hyderabad', 'table': 'location'} in to table

# %%
class DB:
    def __init__(self,data):
        self.data=data
    def insert(self):
        print("insert  the  %s in to table" % self.data)
    def update(self):
        print("update the %s in to table" % self.data)
class Customer(DB):
    pass
class Supplier(DB):
     def insert(self):
        print("validate the address")
        DB.insert(self)
class Product(DB):
     def insert(self):
        print("validate the cost")
        DB.insert(self)
class Location(DB):
    def insert(self):
        print("validate the name")
        DB.insert(self)
cust1 = Customer({"name":"anil","address":"ad1","table":"Customer"})
cust1.insert()
sup1 = Supplier({"name":"sup1","address":"ad2","table":"supplier"})
sup1.insert()
prod1 = Product({"name":"apple","table":"product","cost":23})
prod1.insert()
hyd = Location({"name":"hyderabad","table":"location"})
hyd.insert()
# Out:
# insert  the  {'name': 'anil', 'address': 'ad1', 'table': 'Customer'} in to table
# validate the address
# insert  the  {'name': 'sup1', 'address': 'ad2', 'table': 'supplier'} in to table
# validate the cost
# insert  the  {'name': 'apple', 'table': 'product', 'cost': 23} in to table
# validate the name
# insert  the  {'name': 'hyderabad', 'table': 'location'} in to table

# %%
# what is the need of inheritance..
class Parent:
    def insert(self):
        print("this is insert")
class Child(Parent):
    def update(self):
        print("this is update")
o=Child()
o.update()
o.insert()
# Out:
# this is update
# this is insert

# %%
# what is the need of inheritance..
class Parent:
    def insert(self):
        print("this is insert")
    def update(self):
        print("this is update")
o=Parent()
o.update()
o.insert()
# Out:
# this is update
# this is insert

# %%
# installed paramiko
# paramiko.py
class sshclient:
    def connect(self,username,password,hostname):
        print("using this can connect to linux machines")
# app.py
# from pramiko import sshclient
o=sshclient()
o.connect("user1","pwd1","192.168.247.21")
# Out:
# using this can connect to linux machines

# %%
# installed paramiko:2.1
# paramiko.py
class sshclient:
    def connect(self,username,password,hostname):
        print("using this can connect to linux machines")
    def create_folder(self):
        print("folder created....")
# app.py
# from pramiko import sshclient
o=sshclient()
o.connect("user1","pwd1","192.168.247.21")
o.create_folder()
# Out:
# using this can connect to linux machines
# folder created....

# %%
# whats happen when you install 2.2 version of paramiko to above code? once you update what ever the code
# you writtenin parmiko is erased..
# the soultin is..
# paramiko.py
class sshclient:
    def connect(self,username,password,hostname):
        print("using this can connect to linux machines")
    
# app.py
# from pramiko import sshclient
class Mysshclient(sshclient):
    def create_folder(self):
        print("folder created....")
o=Mysshclient()
o.connect("user1","pwd1","192.168.247.21")
o.create_folder()
# Out:
# using this can connect to linux machines
# folder created....

# %%
d1={"name":"sai"}
d2={"name":"laxmi"}
d1+d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-aaa14da19793> in <module>()
#       1 d1={"name":"sai"}
#       2 d2={"name":"laxmi"}
# ----> 3 d1+d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
class MyOwnDict:
    def __init__(self,data):
        self.data=data
    def __add__(self1,self2):
        return self1.data['name']+self2.data['name']
d1=MyOwnDict({"name":"sai"})
d2=MyOwnDict({"name":"laxmi"})
d1+d2
# Out:
# 'sailaxmi'

# %%
class MyOwnDict:
    def __init__(self,data):
        self.data=data
    def __add__(self1,self2):
        return self1.data['name']+self2.data['name']
d1=MyOwnDict({"name":"sai"})
d2=MyOwnDict({"name":"laxmi"})
print(d1+d2)
print(d1.get("name"))
# Out:
# sailaxmi
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-5994b9a5bf5e> in <module>()
#       7 d2=MyOwnDict({"name":"laxmi"})
#       8 print(d1+d2)
# ----> 9 print(d1.get("name"))
#
# AttributeError: 'MyOwnDict' object has no attribute 'get'

# %%
class MyOwnDict(dict):
    def __add__(self1,self2):
        return self1['name']+self2['name']
d1=MyOwnDict({"name":"sai"})
d2=MyOwnDict({"name":"laxmi"})
print(d1+d2)
print(d1.get("name"))
# Out:
# sailaxmi
# sai

# %%
class Emp:
    company_name="Khyaathi" # class object attribute
    def __init__(self,name,e_id): # name,id are the data object attributes
        self.name=name
        self.id=e_id
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21)
print(sai.get())
# Out:
# ('sailxmi', 21)

# %%
class Emp:
    company_name="Khyaathi" # class object attribute
    def __init__(self,name,e_id): # name,id are the data object attributes
        self.name=name
        self.id=e_id
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21)
print(sai.get())
print(Emp.company_name)
# Out:
# ('sailxmi', 21)
# Khyaathi

# %%
class Emp:
    company_name="Khyaathi" # class object attribute
    def __init__(self,name,e_id): # name,id are the data object attributes
        self.name=name
        self.id=e_id
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21)
print(sai.get())
print(Emp.company_name)
print(Emp.name)
# Out:
# ('sailxmi', 21)
# Khyaathi
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6e28bbfb44a2> in <module>()
#       9 print(sai.get())
#      10 print(Emp.company_name)
# ---> 11 print(Emp.name)
#
# AttributeError: type object 'Emp' has no attribute 'name'

# %%
class Emp:
    company_name="Khyaathi" # class object attribute
    def __init__(self,name,e_id): # name,id are the data object attributes
        self.name=name
        self.id=e_id
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21)
print(sai.get())
print(Emp.company_name)
print(sai.company_name)
# Out:
# ('sailxmi', 21)
# Khyaathi
# Khyaathi

# %%
class Emp:
    print("this is class")
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is init for sailxmi
# this is init for jayaram

# %%
class Emp:
    print("this is class")
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
print(Emp.__mro__)
sai=Emp("sailxmi",21)
jay=Emp("jayaram",13)
# Out:
# this is class
# (<class '__main__.Emp'>, <class 'object'>)
# this is init for sailxmi
# this is init for jayaram

# %%
class Emp:
    print("this is class")
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
print(Emp.__mro__)
sai=Emp("sailxmi",21) # data object creationo is written in __new__ method of object class..
jay=Emp("jayaram",13)
# Out:
# this is class
# (<class '__main__.Emp'>, <class 'object'>)
# this is init for sailxmi
# this is init for jayaram

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
print(Emp.__mro__)
sai=Emp("sailxmi",21) # data object creationo is written in __new__ method of object class.. the new methos itself 
# returns the data object of perticular class.. by taking the data object, will call dataobject.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# (<class '__main__.Emp'>, <class 'object'>)
# this is init for sailxmi
# this is init for jayaram

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __new__(self,*k,**kw):
        print("this is new method of Emp")
        
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
print(Emp.__mro__)
sai=Emp("sailxmi",21) # data object creationo is written in __new__ method of object class.. the new methos itself 
# returns the data object of perticular class.. by taking the data object, will call dataobject.__init__(self,*k,**kw)
jay=Emp("jayaram",13)

# %%
a=10
isinstance(a, int)
# Out:
# True

# %%
a=None
isinstance(a,str)
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a0d4955f32d2> in <module>()
# ----> 1 isinstance(a,None)
#
# TypeError: isinstance() arg 2 must be a type or tuple of types

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __new__(self,*k,**kw):
        print("this is new method of Emp")
        
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21) # Emp new method, the new method  returns the data object of None class..
#by taking the data object, will call none.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is new method of Emp
# this is new method of Emp

# %%
# how can i override the __new__ method in Emp.
class c1:
    def __init__(self):
        print("this is c1 class constructor")
class Emp:
    print("this is class")
    def __new__(self,*k,**kw):
        print("this is new method of Emp")
        return c1()
        
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21) # Emp new method, the new method  returns the data object of None class..
#by taking the data object, will call none.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is new method of Emp
# this is c1 class constructor
# this is new method of Emp
# this is c1 class constructor

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __new__(cls,*k,**kw):
        print("this is new method of Emp")
        obj=object.__new__(cls)
        return obj
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21) # Emp new method, the new method  returns the data object of Emp class..
#by taking the data object, will call Emp.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is new method of Emp
# this is init for sailxmi
# this is new method of Emp
# this is init for jayaram

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __new__(cls,*k,**kw):
        obj=object.__new__(cls)
        return obj
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21) # Emp new method, the new method  returns the data object of Emp class..
#by taking the data object, will call Emp.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is init for sailxmi
# this is init for jayaram

# %%
# how can i override the __new__ method in Emp.
class Emp:
    print("this is class")
    def __init__(self,name,e_id):
        self.name=name
        self.id=e_id
        print("this is init for %s"%self.name)
    def get(self):
        return self.name,self.id
sai=Emp("sailxmi",21) # Emp new method, the new method  returns the data object of Emp class..
#by taking the data object, will call Emp.__init__(self,*k,**kw)
jay=Emp("jayaram",13)
# Out:
# this is class
# this is init for sailxmi
# this is init for jayaram
